# %% [raw]
# ---
# description: Training notebook for this architecture.
# output-file: _11_efficientnet-unet.html
# title: Training EfficientNet-UNET
#
# ---

# %%
#| include: false
#all_slow

# %%
#| include: false
# !pip install -Uqq fastai --upgrade
# !pip install -Uqq fastcore --upgrade

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/marcomatteo/steel_segmentation/blob/master/nbs/11_resnet18-UNET.ipynb)

# %%
#| include: false
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from steel_segmentation.all import *

import cv2
import fastai
import torch
import numpy as np
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *

import albumentations as alb
import segmentation_models_pytorch as smp

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu"); device
# Out:
# device(type='cuda')

# %%
fastai.__version__, torch.__version__
# Out:
# ('2.3.1', '1.7.1+cu101')

# %%
torch.cuda.device_count(), torch.cuda.is_available()
# Out:
# (1, True)

# %%
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri May 14 12:46:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 450.36.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro M4000        On   | 00000000:00:05.0 Off |                  N/A |
# | 46%   25C    P8    11W / 120W |      4MiB /  8126MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#| include: false
seed_everything()

# %% [markdown]
# ## Data

# %%
cond = train_pivot[0] != -1 # no common hard negatives
df = train_pivot.loc[cond]
df.shape
# Out:
# (6666, 6)

# %%
def get_train_aug(height, width, with_gray=False): 
    #alb.CropNonEmptyMaskIfExists(height, width, p=0.5), #added after stage-1
    first_step = alb.RandomCrop(height, width, p=1.0)
    
    second_step = alb.OneOf([alb.VerticalFlip(p=0.5),
                              alb.HorizontalFlip(p=0.5)
                             ], p=0.5)
    
    third_step = alb.OneOf([
        alb.RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), 
                                     contrast_limit=(-0.2, 0.2), 
                                     brightness_by_max=True,
                                     p=0.5),
        alb.RandomGridShuffle(always_apply=False, p=0.2, grid=(1, 2))], p=0.5)
    
    # to do: try with grayscale imgs
    gray_step = alb.ToGray(always_apply=False, p=1.0)
    return alb.Compose([first_step, second_step, third_step] + ([gray_step] if with_gray else []))

def get_valid_aug(height, width, with_gray=False): 
    first_step = alb.RandomCrop(height, width)
    gray_step = alb.ToGray(always_apply=False, p=1.0)
    return alb.Compose([first_step] + ([gray_step] if with_gray else []))

# %%
size = (224,1568)
# size = (128,896)

# %%
train_tfms = get_train_aug(*size)
valid_tfms = get_valid_aug(*size)

# %%
block = DataBlock(blocks = (ImageBlock,SteelMaskBlock(codes=[1,2,3,4])),
                  get_x = ReadImagePathFromIndex,
                  get_y = ReadRLEs(cols=[1,2,3,4]),
                  splitter = TrainTestSplitter(test_size=0.2),
                  item_tfms=[AlbumentationsTransform(train_tfms, valid_tfms)],
                  batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
ds = block.datasets(df)

img, mask = ds.valid[1]
ax = img.show(figsize=(15,5))
mask.show(ctx=ax);

# %% [markdown]
# Saving the image list that are used to training and for validation for testing.

# %%
imgids_array = ds.train.items.index.drop_duplicates().values
np.savetxt(path/"train_imgids.txt", imgids_array, fmt="%s")

# %%
imgids_array = ds.valid.items.index.drop_duplicates().values
np.savetxt(path/"valid_imgids.txt", imgids_array, fmt="%s")

# %% [markdown]
# ## SMP - Training

# %%
dls = block.dataloaders(source=df, 
                        bs=8, 
                        device=device, 
                        num_workers=2)

# %%
x,y = dls.valid.one_batch()
x.shape, y.shape
# Out:
# (torch.Size([8, 3, 224, 1568]), torch.Size([8, 4, 224, 1568]))

# %%
dls.show_batch(ncols=2, figsize=(15,5))

# %%
arch = smp.Unet('efficientnet-b2', classes=4, activation=None, 
                encoder_weights='imagenet')
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b2-8bb594d6.pth
# HBox(children=(FloatProgress(value=0.0, max=36804509.0), HTML(value='')))

# %%
# to load the weights into the arch use
arch.load_state_dict(torch.load(models_dir/("efficientnet_b2-UNET-stage0.pth")))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ![UNET Architecture](../imgs/unet.png)

# %%
def opt_func(params, **kwargs): return OptimWrapper(params, torch.optim.Adam, **kwargs)
def splitter(m): return convert_params([[m.encoder], [m.decoder], [m.segmentation_head]])

# %%
learn = Learner(dls=dls, 
                model=arch, 
                loss_func=BCEWithLogitsLossFlat(axis=1),
                metrics=[ModDiceMulti(with_logits=True)], 
                splitter=splitter, 
                opt_func=opt_func, 
                model_dir=models_dir,
                path=models_dir,
                cbs=[ShowGraphCallback()]).to_fp16()

# %%
#learn.freeze_to(-2)
learn.unfreeze()

# %%
learn.summary()
# Out:
# Unet (Input shape: 8)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      []
# ZeroPad2d
# BatchNorm2d                               64         True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               64         True
# Identity
# Identity
# Identity
# BatchNorm2d                               32         True
# MemoryEfficientSwish
# ZeroPad2d
# BatchNorm2d                               32         True
# Identity
# Identity
# Identity
# BatchNorm2d                               32         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               192        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               192        True
# Identity
# Identity
# Identity
# BatchNorm2d                               48         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               288        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               288        True
# Identity
# Identity
# Identity
# BatchNorm2d                               48         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               288        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               288        True
# Identity
# Identity
# Identity
# BatchNorm2d                               48         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               288        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               288        True
# Identity
# Identity
# Identity
# BatchNorm2d                               96         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               576        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               576        True
# Identity
# Identity
# Identity
# BatchNorm2d                               96         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               576        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               576        True
# Identity
# Identity
# Identity
# BatchNorm2d                               96         True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               576        True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               576        True
# Identity
# Identity
# Identity
# BatchNorm2d                               176        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1056       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1056       True
# Identity
# Identity
# Identity
# BatchNorm2d                               176        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1056       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1056       True
# Identity
# Identity
# Identity
# BatchNorm2d                               176        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1056       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1056       True
# Identity
# Identity
# Identity
# BatchNorm2d                               176        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1056       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1056       True
# Identity
# Identity
# Identity
# BatchNorm2d                               240        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1440       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1440       True
# Identity
# Identity
# Identity
# BatchNorm2d                               240        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1440       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1440       True
# Identity
# Identity
# Identity
# BatchNorm2d                               240        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1440       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1440       True
# Identity
# Identity
# Identity
# BatchNorm2d                               240        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               1440       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               1440       True
# Identity
# Identity
# Identity
# BatchNorm2d                               416        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               2496       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               2496       True
# Identity
# Identity
# Identity
# BatchNorm2d                               416        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               2496       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               2496       True
# Identity
# Identity
# Identity
# BatchNorm2d                               416        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               2496       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               2496       True
# Identity
# Identity
# Identity
# BatchNorm2d                               416        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               2496       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               2496       True
# Identity
# Identity
# Identity
# BatchNorm2d                               416        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               2496       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               2496       True
# Identity
# Identity
# Identity
# BatchNorm2d                               704        True
# MemoryEfficientSwish
# Identity
# BatchNorm2d                               4224       True
# ____________________________________________________________________________
#                      []
# ZeroPad2d
# BatchNorm2d                               4224       True
# Identity
# Identity
# Identity
# BatchNorm2d                               704        True
# MemoryEfficientSwish
# MemoryEfficientSwish
# Identity
# ____________________________________________________________________________
#                      8 x 256 x 14 x 98
# Conv2d                                    1087488    True
# BatchNorm2d                               512        True
# ReLU
# Identity
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 128 x 28 x 196
# Conv2d                                    350208     True
# BatchNorm2d                               256        True
# ReLU
# Identity
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 64 x 56 x 392
# Conv2d                                    87552      True
# BatchNorm2d                               128        True
# ReLU
# Identity
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 32 x 112 x 784
# Conv2d                                    27648      True
# BatchNorm2d                               64         True
# ReLU
# Identity
# Conv2d                                    9216       True
# BatchNorm2d                               64         True
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 16 x 224 x 1568
# Conv2d                                    4608       True
# BatchNorm2d                               32         True
# ReLU
# Conv2d                                    2304       True
# BatchNorm2d                               32         True
# ReLU
# Identity
# ____________________________________________________________________________
#                      8 x 4 x 224 x 1568
# Conv2d                                    580        True
# Identity
# Identity
# ____________________________________________________________________________
#
# Total params: 2,410,484
# Total trainable params: 2,410,484
# Total non-trainable params: 0
#
# Optimizer used: <function opt_func at 0x7f76be724700>
# Loss function: FlattenedLoss of BCEWithLogitsLoss()
#
# Model unfrozen
#
# Callbacks:
#   - TrainEvalCallback
#   - MixedPrecision
#   - Recorder
#   - ProgressCallback
#   - ShowGraphCallback

# %% [markdown]
# Due to misconception I previously trained the model without augmentations.

# %%
stage = "efficientnet_b2-UNET-stage0"

# %%
fit_cbs = [
    GradientAccumulation(n_acc=16),
    ReduceLROnPlateau(monitor='valid_loss', patience=2),
    CSVLogger(fname=f'{models_dir}/logs/{stage}.csv'),
    SaveModelCallback(monitor='valid_loss', fname=stage)]

# %%
#test
learn.dls = block.dataloaders(df.iloc[:1000], bs=8, num_workers=0)
learn.fit(5, lr=4e-4, cbs=fit_cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mod_dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.513457</td>
#       <td>0.393795</td>
#       <td>0.252899</td>
#       <td>04:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.290152</td>
#       <td>0.188096</td>
#       <td>0.286804</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.153328</td>
#       <td>0.104251</td>
#       <td>0.388386</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.090937</td>
#       <td>0.067388</td>
#       <td>0.403346</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.062011</td>
#       <td>0.048192</td>
#       <td>0.506705</td>
#       <td>04:29</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3937946557998657.
# Better model found at epoch 1 with valid_loss value: 0.18809622526168823.
# Better model found at epoch 2 with valid_loss value: 0.10425052791833878.
# Better model found at epoch 3 with valid_loss value: 0.06738794595003128.
# Better model found at epoch 4 with valid_loss value: 0.04819217696785927.

# %% [markdown]
# After this test, you need to reload the notebook.

# %%
learn.fit_one_cycle(15, lr_max=5e-4, div=5., cbs=fit_cbs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [10/15 4:59:23<2:29:41]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mod_dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.197872</td>
#       <td>0.150238</td>
#       <td>0.492619</td>
#       <td>30:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.045045</td>
#       <td>0.041623</td>
#       <td>0.623954</td>
#       <td>29:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.027921</td>
#       <td>0.027541</td>
#       <td>0.601422</td>
#       <td>29:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022508</td>
#       <td>0.024429</td>
#       <td>0.596927</td>
#       <td>29:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019809</td>
#       <td>0.019002</td>
#       <td>0.633043</td>
#       <td>29:49</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.018687</td>
#       <td>0.020704</td>
#       <td>0.631026</td>
#       <td>29:56</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.016174</td>
#       <td>0.018414</td>
#       <td>0.635311</td>
#       <td>29:48</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.014258</td>
#       <td>0.018302</td>
#       <td>0.623572</td>
#       <td>29:44</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.012443</td>
#       <td>0.018229</td>
#       <td>0.636347</td>
#       <td>29:48</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.010727</td>
#       <td>0.018082</td>
#       <td>0.638715</td>
#       <td>30:09</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='614' class='' max='666' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       92.19% [614/666 25:06<02:07 0.0104]
#     </div>
# Better model found at epoch 0 with valid_loss value: 0.150238037109375.
# Better model found at epoch 1 with valid_loss value: 0.04162340238690376.
# Better model found at epoch 2 with valid_loss value: 0.027541441842913628.
# Better model found at epoch 3 with valid_loss value: 0.02442856691777706.
# Better model found at epoch 4 with valid_loss value: 0.019001780077815056.
# Better model found at epoch 6 with valid_loss value: 0.018414458259940147.
# Better model found at epoch 7 with valid_loss value: 0.0183021891862154.
# Better model found at epoch 8 with valid_loss value: 0.018228640779852867.
# Better model found at epoch 9 with valid_loss value: 0.018082445487380028.

# %% [markdown]
# The training was interrupted by paperspace time constrain. So I reload the best model founded in the last epoch.

# %%
stage = "efficientnet_b2-UNET-stage0"
loaded_learn = learn.load(stage)

# %%
stage = "efficientnet_b2-UNET-stage1"

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=6.309573450380412e-08, lr_steep=6.918309736647643e-06)

# %%
fit_cbs = [
    GradientAccumulation(n_acc=16),
    ReduceLROnPlateau(monitor='valid_loss', patience=2),
    CSVLogger(fname=f'{models_dir}/logs/{stage}.csv'),
    SaveModelCallback(monitor='valid_loss', fname=stage)]

# %%
learn.fit_one_cycle(5, lr_max=5e-5, cbs=fit_cbs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mod_dice_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013957</td>
#       <td>0.018091</td>
#       <td>0.637402</td>
#       <td>23:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.014026</td>
#       <td>0.017652</td>
#       <td>0.642263</td>
#       <td>23:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.013477</td>
#       <td>0.017495</td>
#       <td>0.640626</td>
#       <td>23:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014106</td>
#       <td>0.017077</td>
#       <td>0.643088</td>
#       <td>23:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.014371</td>
#       <td>0.017249</td>
#       <td>0.642605</td>
#       <td>23:06</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.018091311678290367.
# Better model found at epoch 1 with valid_loss value: 0.01765170693397522.
# Better model found at epoch 2 with valid_loss value: 0.01749509759247303.
# Better model found at epoch 3 with valid_loss value: 0.017076779156923294.

# %% [markdown]
# ## Results

# %%
learn.show_results(figsize=(15,10))

# %%
learn.show_results(figsize=(15,10))

# %%
learn.show_results(figsize=(15,10))

# %% [markdown]
# ## Deployment

# %% [markdown]
# Export the learner for inference:

# %%
device_cpu = torch.device("cpu")
block_exp = DataBlock(blocks = (ImageBlock,SteelMaskBlock(codes=[1,2,3,4])),
                  get_x = ReadImagePathFromIndex,
                  get_y = ReadRLEs(cols=[1,2,3,4]),
                  splitter = TrainTestSplitter(test_size=0.2))
dls_exp = block_exp.dataloaders(source=df, bs=8, device=device_cpu, num_workers=0)
learn_exp = Learner(dls=dls_exp, 
                    model=arch, 
                    loss_func=BCEWithLogitsLossFlat(axis=1),
                    metrics=[ModDiceMulti(with_logits=True)], 
                    splitter=splitter, 
                    opt_func=opt_func, 
                    model_dir=models_dir,
                    path=models_dir)
stage = "efficientnet_b2-UNET-stage0"
learn_exp.model = learn_exp.load(stage, device=device_cpu).cpu()
learn_exp.export("exports/efficientnet-b2.pkl")
# Out:
# Could not do one pass in your dataloader, there is something wrong in it

# %% [markdown]
# Checking to the exported learner:

# %%
loaded_learn_pkl = load_learner(models_dir/"exports"/"efficientnet-b2.pkl", cpu=True)

# %%
loaded_learn_pkl.validate()
# Out:
# (#2) [0.01974334567785263,0.6359560701732629]

# %%
rles, preds, probs = loaded_learn_pkl.predict(img)

# %%
plot_mask_image("Predicted", np.array(img), preds.permute(1,2,0).float().numpy())
